# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-dbde1ef99e51> in <module>()
#       1 import os
# ----> 2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# /usr/lib/python2.7/dist-packages/numpy/__init__.py in <module>()
#     178         return loader(*packages, **options)
#     179
# --> 180     from . import add_newdocs
#     181     __all__ = ['add_newdocs',
#     182                'ModuleDeprecationWarning',
#
# /usr/lib/python2.7/dist-packages/numpy/add_newdocs.py in <module>()
#      11 from __future__ import division, absolute_import, print_function
#      12
# ---> 13 from numpy.lib import add_newdoc
#      14
#      15 ###############################################################################
#
# /usr/lib/python2.7/dist-packages/numpy/lib/__init__.py in <module>()
#       6 from numpy.version import version as __version__
# ...

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-5a0bd626bb1d> in <module>()
# ----> 1 import numpy
#
# /usr/lib/python2.7/dist-packages/numpy/__init__.py in <module>()
#     178         return loader(*packages, **options)
#     179
# --> 180     from . import add_newdocs
#     181     __all__ = ['add_newdocs',
#     182                'ModuleDeprecationWarning',
#
# /usr/lib/python2.7/dist-packages/numpy/add_newdocs.py in <module>()
#      11 from __future__ import division, absolute_import, print_function
#      12
# ---> 13 from numpy.lib import add_newdoc
#      14
#      15 ###############################################################################
#
# /usr/lib/python2.7/dist-packages/numpy/lib/__init__.py in <module>()
#       6 from numpy.version import version as __version__
#       7
# ----> 8 from .type_check import *
# ...
